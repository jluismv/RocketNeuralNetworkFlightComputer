# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    GRU,
    Bidirectional,
    GaussianNoise,
    BatchNormalization,
    Conv1D,
    MaxPooling1D
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber
# 1. CONFIGURACIÓN
PROCESSED_PATH = Path(r"C:\TensorFlow\RocketNeuralNetworkFlightComputer\Data\Processed Data\Augmented")
WINDOW_SIZE = 201
FEATURES_LSTM = ["baro_altitude","accl_x","accl_y","accl_z","At","P"]
# 2. LOCALIZAR ARCHIVOS
archivos_originales = list(PROCESSED_PATH.glob("*.csv"))
print("EXTRACCIÓN DE DATOS")
print("Ruta:")
print(PROCESSED_PATH)
print(f"\nArchivos CSV encontrados: {len(archivos_originales)}")
if len(archivos_originales) == 0:

    raise ValueError( "\nNO SE ENCONTRARON ARCHIVOS CSV.\n""Revisa que la ruta sea exactamente:\n"r"C:\TensorFlow\RocketNeuralNetworkFlightComputer\Data\Processed Data\Augmented")

# 3. EXTRACCIÓN DE SECUENCIAS
X_seq = []
y_seq = []
base_ids = []
archivos_procesados = 0
archivos_descartados_altura = 0
archivos_sin_despegue = 0
archivos_ventana_corta = 0

for archivo in archivos_originales:
    try:
        df = pd.read_csv(archivo)
        df.columns = df.columns.str.strip()
        columnas_necesarias = [ "time","baro_altitude", "accl_x","accl_y","accl_z"]
        faltantes = [c for c in columnas_necesarias if c not in df.columns ]
        if len(faltantes) > 0:
            print(
                f"\nDescartado {archivo.name}"
                f" -> faltan columnas: {faltantes}"
            )

            continue
        # Orden temporal
        df = df.sort_values("time").reset_index(drop=True)
        # Eliminar NaN en variables principales
        df = df.dropna(
            subset=["baro_altitude","accl_x","accl_y","accl_z" ]).reset_index(drop=True)

        if len(df) == 0:
            continue
        # RECONSTRUCCIÓN DE CARACTERÍSTICAS
        # Aceleración total
        if "At" not in df.columns:
            df["At"] = np.sqrt(
                df["accl_x"]**2 +
                df["accl_y"]**2 +
                df["accl_z"]**2
            )
        # Presión atmosférica
        if "P" not in df.columns:
            df["P"] = (101325.0 *(1 - 2.25577e-5 * df["baro_altitude"])**5.25588 )
        # Eliminar valores no válidos
        df = df.replace([np.inf, -np.inf],np.nan)
        df = df.dropna(
            subset=FEATURES_LSTM
        ).reset_index(drop=True)
        if len(df) == 0:
            continue
        # APOGEO REAL
        apogeo_real = float(
            df["baro_altitude"].max()
        )
        # Filtro físico
        if apogeo_real > 4500:
            archivos_descartados_altura += 1
            continue
        # Evitar objetivos absurdos o negativos
        if apogeo_real <= 0:
            continue
        # TRIGGER DE DESPEGUE
        despegues = df.index[df["At"] > 15]
        if len(despegues) == 0:
            archivos_sin_despegue += 1
            continue
        idx_despegue = int(
            despegues[0]
        )
        # EXTRAER VENTANA
        window = df.iloc[
            idx_despegue:
            idx_despegue + WINDOW_SIZE
        ]
        if len(window) != WINDOW_SIZE:
            archivos_ventana_corta += 1
            continue
        # GUARDAR
        X_seq.append(
            window[FEATURES_LSTM].values
        )
        y_seq.append(
            apogeo_real
        )
        base_ids.append(
            archivo.stem
        )
        archivos_procesados += 1
    except Exception as e:
        print(
            f"\nError procesando {archivo.name}: {e}"
        )
# 4. CONVERTIR A NUMPY
X_temporal = np.array(
    X_seq,
    dtype=np.float32
)
y_temporal = np.array(
    y_seq,
    dtype=np.float32
)
flight_ids_temporal = np.array(
    base_ids
)
# 5. DIAGNÓSTICO DE DATOS
print("DIAGNÓSTICO DE DATOS")
print(f"Archivos originales       : {len(archivos_originales)}")
print(f"Archivos procesados       : {archivos_procesados}")
print(f"Descartados por >4500 m   : "f"{archivos_descartados_altura}")
print(f"Sin trigger de despegue   : "f"{archivos_sin_despegue}")
print(f"Ventana insuficiente      : "f"{archivos_ventana_corta}")
print(f"\nX_temporal: {X_temporal.shape}")
print(f"y_temporal: {y_temporal.shape}")
print(f"Vuelos únicos: "f"{len(np.unique(flight_ids_temporal))}")
# 6. PROTECCIÓN CONTRA DATASET VACÍO
if len(X_temporal) == 0:

    raise ValueError(
        "\nERROR: X_temporal está vacío.\n\n"
        "El problema está en la extracción de los CSV, "
        "no en la red neuronal.\n\n"
        "Revisa principalmente:\n"
        "1. La ruta.\n"
        "2. Las columnas de los CSV.\n"
        "3. El trigger At > 15.\n"
        "4. Que existan al menos 201 muestras después del despegue."
    )
# 7. TRANSFORMACIÓN DEL OBJETIVO
y_temporal_log = np.log1p(y_temporal)
# 8. GRUPOS POR VUELO
unique_base_ids = np.unique(flight_ids_temporal)

if len(unique_base_ids) < 3:
    print("\n⚠️ Menos de 3 vuelos.")
    grupos_kfold = np.arange(len(X_temporal))
else:
    grupos_kfold = flight_ids_temporal
# 9. MODELO V10
def build_gru_v10(input_shape):
    model = Sequential(name="GRU_V10")
    model.add(Input(shape=input_shape))
    model.add(GaussianNoise(0.01))
    model.add(Conv1D(filters=64, kernel_size=3, activation="relu", padding="causal"))  # <- causal, no "same"
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    # Antes: Bidirectional(GRU(96, ...))
    model.add(GRU(96, return_sequences=False, dropout=0.2, kernel_regularizer=l2(0.0005)))
    model.add(BatchNormalization())
    model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.0005)))
    model.add(Dropout(0.15))
    model.add(Dense(1))

    optimizer = tf.keras.optimizers.AdamW(learning_rate=5e-4, weight_decay=1e-4, clipnorm=1.0)
    model.compile(optimizer=optimizer, loss=Huber(), metrics=["mae"])
    return model
# 10. VALIDACIÓN GROUP K-FOLD
def groupkfold_evaluate_lstm(build_fn,X,y,groups,n_splits=5,epochs=120,batch_size=32,patience=20):
    n_splits = min(n_splits,len(np.unique(groups)))
    gkf = GroupKFold(n_splits=n_splits)
    fold_metrics = []
    for fold, (train_idx, val_idx) in enumerate(
        gkf.split(X,y,groups)):
        tf.keras.backend.clear_session()
        print("\n" + "=" * 60)
        print(
            f"FOLD {fold + 1}/{n_splits}"
        )
        print("=" * 60)
        # DATOS DEL FOLD
        X_train_f = X[train_idx]
        X_val_f = X[val_idx]
        y_train_f = y[ train_idx]
        y_val_f = y[val_idx]
        # ESCALADO X
        n_features = X_train_f.shape[2]
        scaler_X = StandardScaler()
        X_train_scaled = scaler_X.fit_transform(
            X_train_f.reshape(
                -1,
                n_features
            )
        ).reshape(
            X_train_f.shape
        )
        X_val_scaled = scaler_X.transform(
            X_val_f.reshape(
                -1,
                n_features
            )
        ).reshape(
            X_val_f.shape
        )
        # ESCALADO Y
        scaler_y = RobustScaler()
        y_train_scaled = scaler_y.fit_transform(
            y_train_f.reshape(
                -1,
                1
            )
        ).ravel()
        y_val_scaled = scaler_y.transform(
            y_val_f.reshape(
                -1,
                1
            )
        ).ravel()
        # CREAR MODELO
        model = build_fn(
            input_shape=(
                X_train_scaled.shape[1],
                X_train_scaled.shape[2]
            )
        )
        # CALLBACKS
        early_stop = tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=patience,
            restore_best_weights=True,
            verbose=1
        )
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=8,
            min_lr=1e-5,
            verbose=1
        )
        # ENTRENAMIENTO
        history = model.fit(
            X_train_scaled,
            y_train_scaled,
            validation_data=(
                X_val_scaled,
                y_val_scaled
            ),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=[
                early_stop,
                reduce_lr
            ],
            verbose=1
        )
        # PREDICCIÓN
        preds_scaled = model.predict(
            X_val_scaled,
            verbose=0
        ).ravel()
        # DESHACER ESCALADO
        y_pred_log = scaler_y.inverse_transform(
            preds_scaled.reshape(
                -1,
                1
            )
        ).ravel()
        # VOLVER A METROS
        y_pred_metros = np.expm1(y_pred_log)
        y_true_metros = np.expm1(y_val_f)
        # Evitar predicciones negativas
        y_pred_metros = np.maximum(y_pred_metros,0)
        # MÉTRICAS
        mae = mean_absolute_error(
y_true_metros,
            y_pred_metros
        )
        rmse = np.sqrt(
            mean_squared_error(
                y_true_metros,
                y_pred_metros
            )
        )
        r2 = r2_score(
            y_true_metros,
            y_pred_metros
        )
        print("\nRESULTADOS FOLD")
        print(f"MAE  : {mae:.2f} m")
        print( f"RMSE : {rmse:.2f} m")
        print( f"R2  : {r2:.4f}")
        fold_metrics.append(
            {"MAE": mae,"RMSE": rmse,"R2": r2,"y_true": y_true_metros,"y_pred": y_pred_metros,"history": history })
    return fold_metrics
# 11. RESUMEN
def summarize_cv(fold_metrics,name):
    maes = [m["MAE"]for m in fold_metrics]
    rmses = [m["RMSE"]for m in fold_metrics]
    r2s = [m["R2"]for m in fold_metrics]
    print("\n")
    print("=" * 60)
    print(
        f"RESUMEN {name}"
    )
    print("=" * 60)
    print(f"MAE  : "f"{np.mean(maes):.2f} "f"± {np.std(maes):.2f} m")
    print(f"RMSE : "f"{np.mean(rmses):.2f} "f"± {np.std(rmses):.2f} m")
    print( f"R2   : "f"{np.mean(r2s):.4f}")
    print("=" * 60)
# 12. GRÁFICAS
def plot_kfold_diagnostics(fold_metrics):
    n_folds = len(fold_metrics)
    fig, axes = plt.subplots(
        1,
        n_folds,
        figsize=(
            4.5 * n_folds,
            5
        ),
        sharey=True
    )
    if n_folds == 1:
        axes = [axes]
    for i, ax in enumerate(axes):
        y_true = fold_metrics[i]["y_true"]
        y_pred = fold_metrics[i]["y_pred"]
        r2 = fold_metrics[i][ "R2"]
        ax.scatter(y_true,y_pred,alpha=0.7,c="#1f77b4",edgecolors="k")
        min_val = min(np.min(y_true),np.min(y_pred))
        max_val = max(np.max(y_true),np.max(y_pred))
        ax.plot([min_val, max_val],[min_val, max_val],"r--",lw=2,label="Predicción ideal")
        ax.axvline(3000,color="green",linestyle=":",lw=2,label="Meta 3000 m")
        ax.axhline(3000,color="green",linestyle=":",lw=2)
        ax.set_title(f"Fold {i + 1} | R² = {r2:.2f}")
        ax.set_xlabel("Apogeo real (m)")
        if i == 0:
            ax.set_ylabel("Apogeo predicho (m)")
            ax.legend()
        ax.grid( True,linestyle="--",alpha=0.7)
    plt.suptitle("LSTM V9  Auditoría de Vuelos",fontsize=14,y=1.05)
    plt.tight_layout()
    plt.show()
# 13. EJECUCIÓN
print("\n")
print("LSTM V10 ")
print(f"Dataset: {X_temporal.shape}")
print(f"Ventana: {WINDOW_SIZE}")
print(f"Características: {len(FEATURES_LSTM)}")
print(f"Vuelos: {len(unique_base_ids)}")

cv_lstm_v10_folds = groupkfold_evaluate_lstm(
    build_fn=build_gru_v10,
    X=X_temporal,
    y=y_temporal_log,
    groups=grupos_kfold,
    n_splits=5,
    epochs=120,
    batch_size=32,
    patience=20
)
# 14. RESULTADOS
summarize_cv(
    cv_lstm_v10_folds,
    "LSTM V10"
)
# 15. GRÁFICAS
plot_kfold_diagnostics(
    cv_lstm_v10_folds
)
# Out:
# EXTRACCIÓN DE DATOS
# Ruta:
# C:\TensorFlow\RocketNeuralNetworkFlightComputer\Data\Processed Data\Augmented
#
# Archivos CSV encontrados: 620
# DIAGNÓSTICO DE DATOS
# Archivos originales       : 620
# Archivos procesados       : 580
# Descartados por >4500 m   : 30
# Sin trigger de despegue   : 0
# Ventana insuficiente      : 10
#
# X_temporal: (580, 201, 6)
# y_temporal: (580,)
# Vuelos únicos: 580
#
#
# LSTM V10
# Dataset: (580, 201, 6)
# Ventana: 201
# Características: 6
# Vuelos: 580
#
# ============================================================
# FOLD 1/5
# ============================================================
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - loss: 0.4144 - mae: 0.6857 - val_loss: 0.1926 - val_mae: 0.4164 - learning_rate: 5.0000e-04
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.2602 - mae: 0.4701 - val_loss: 0.1865 - val_mae: 0.4025 - learning_rate: 5.0000e-04
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.2269 - mae: 0.4323 - val_loss: 0.1840 - val_mae: 0.3928 - learning_rate: 5.0000e-04
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1963 - mae: 0.3790 - val_loss: 0.1785 - val_mae: 0.3931 - learning_rate: 5.0000e-04
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.1597 - mae: 0.3271 - val_loss: 0.1689 - val_mae: 0.3664 - learning_rate: 5.0000e-04
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.1568 - mae: 0.3140 - val_loss: 0.1725 - val_mae: 0.3773 - learning_rate: 5.0000e-04
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.1458 - mae: 0.2879 - val_loss: 0.1586 - val_mae: 0.3478 - learning_rate: 5.0000e-04
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1297 - mae: 0.2649 - val_loss: 0.1492 - val_mae: 0.3220 - learning_rate: 5.0000e-04
# Epoch 9/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1309 - mae: 0.2686 - val_loss: 0.1411 - val_mae: 0.3069 - learning_rate: 5.0000e-04
# Epoch 10/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.1137 - mae: 0.2325 - val_loss: 0.1312 - val_mae: 0.2862 - learning_rate: 5.0000e-04
# Epoch 11/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0
120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0496 - mae: 0.1255 - val_loss: 0.0386 - val_mae: 0.0410 - learning_rate: 5.0000e-04
# Epoch 85/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0509 - mae: 0.1322 - val_loss: 0.0382 - val_mae: 0.0383 - learning_rate: 5.0000e-04
# Epoch 86/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0479 - mae: 0.1178 - val_loss: 0.0392 - val_mae: 0.0579 - learning_rate: 5.0000e-04
# Epoch 87/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0487 - mae: 0.1181 - val_loss: 0.0375 - val_mae: 0.0337 - learning_rate: 5.0000e-04
# Epoch 88/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0486 - mae: 0.1199 - val_loss: 0.0393 - val_mae: 0.0590 - learning_rate: 5.0000e-04
# Epoch 89/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0478 - mae: 0.1158 - val_loss: 0.0395 - val_mae: 0.0673 - learning_rate: 5.0000e-04
# Epoch 90/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0463 - mae: 0.1109 - val_loss: 0.0378 - val_mae: 0.0448 - learning_rate: 5.0000e-04
# Epoch 91/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0475 - mae: 0.1161 - val_loss: 0.0404 - val_mae: 0.0781 - learning_rate: 5.0000e-04
# Epoch 92/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0508 - mae: 0.1349 - val_loss: 0.0374 - val_mae: 0.0492 - learning_rate: 5.0000e-04
# Epoch 93/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0466 - mae: 0.1163 - val_loss: 0.0367 - val_mae: 0.0422 - learning_rate: 5.0000e-04
# Epoch 94/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0455 - mae: 0.1102 - val_loss: 0.0373 - val_mae: 0.0534 - learning_rate: 5.0000e-04
# Epoch 95/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0472 - mae: 0.1189 - val_loss: 0.0366 - val_mae: 0.0412 - learning_rate: 5.0000e-04
# Epoch 96/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0478 - mae: 0.1269 - val_loss: 0.0396 - val_mae: 0.0821 - learning_rate: 5.0000e-04
# Epoch 97/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0483 - mae: 0.1292 - val_loss: 0.0364 - val_mae: 0.0535 - learning_rate: 5.0000e-04
# Epoch 98/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0444 - mae: 0.1121 - val_loss: 0.0355 - val_mae: 0.0411 - learning_rate: 5.0000e-04
# Epoch 99/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0441 - mae: 0.1094 - val_loss: 0.0353 - val_mae: 0.0420 - learning_rate: 5.0000e-04
# Epoch 100/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0480 - mae: 0.1331 - val_loss: 0.0352 - val_mae: 0.0391 - learning_rate: 5.0000e-04
# Epoch 101/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0447 - mae: 0.1122 - val_loss: 0.0357 - val_mae: 0.0513 - learning_rate: 5.0000e-04
# Epoch 102/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0436 - mae: 0.1057 - val_loss: 0.0356 - val_mae: 0.0571 - learning_rate: 5.0000e-04
# Epoch 103/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0458 - mae: 0.1219 - val_loss: 0.0352 - val_mae: 0.0490 - learning_rate: 5.0000e-04
# Epoch 104/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0434 - mae: 0.1144 - val_loss: 0.0345 - val_mae: 0.0453 - learning_rate: 5.0000e-04
# Epoch 105/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0422 - mae: 0.1068 - val_loss: 0.0346 - val_mae: 0.0495 - learning_rate: 5.0000e-04
# Epoch 106/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0432 - mae: 0.1139 - val_loss: 0.0336 - val_mae: 0.0357 - learning_rate: 5.0000e-04
# Epoch 107/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0436 - mae: 0.1159 - val_loss: 0.0343 - val_mae: 0.0447 - learning_rate: 5.0000e-04
# Epoch 108/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0426 - mae: 0.1144 - val_loss: 0.0336 - val_mae: 0.0427 - learning_rate: 5.0000e-04
# Epoch 109/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0438 - mae: 0.1203 - val_loss: 0.0347 - val_mae: 0.0611 - learning_rate: 5.0000e-04
# Epoch 110/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0426 - mae: 0.1139 - val_loss: 0.0344 - val_mae: 0.0523 - learning_rate: 5.0000e-04
# Epoch 111/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0430 - mae: 0.1199 - val_loss: 0.0327 - val_mae: 0.0372 - learning_rate: 5.0000e-04
# Epoch 112/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0424 - mae: 0.1135 - val_loss: 0.0325 - val_mae: 0.0334 - learning_rate: 5.0000e-04
# Epoch 113/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0429 - mae: 0.1165 - val_loss: 0.0338 - val_mae: 0.0518 - learning_rate: 5.0000e-04
# Epoch 114/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0423 - mae: 0.1111 - val_loss: 0.0324 - val_mae: 0.0417 - learning_rate: 5.0000e-04
# Epoch 115/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0413 - mae: 0.1123 - val_loss: 0.0322 - val_mae: 0.0399 - learning_rate: 5.0000e-04
# Epoch 116/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0420 - mae: 0.1164 - val_loss: 0.0321 - val_mae: 0.0416 - learning_rate: 5.0000e-04
# Epoch 117/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0410 - mae: 0.1125 - val_loss: 0.0334 - val_mae: 0.0631 - learning_rate: 5.0000e-04
# Epoch 118/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0384 - mae: 0.0977 - val_loss: 0.0319 - val_mae: 0.0400 - learning_rate: 5.0000e-04
# Epoch 119/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0388 - mae: 0.1000 - val_loss: 0.0315 - val_mae: 0.0407 - learning_rate: 5.0000e-04
# Epoch 120/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0403 - mae: 0.1063 - val_loss: 0.0312 - val_mae: 0.0374 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 120.
#
# RESULTADOS FOLD
# MAE  : 56.07 m
# RMSE : 94.49 m
# R2  : 0.9885
#
# ============================================================
# FOLD 2/5
# ============================================================
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 166ms/step - loss: 0.4011 - mae: 0.6725 - val_loss: 0.2803 - val_mae: 0.5697 - learning_rate: 5.0000e-04
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.2704 - mae: 0.4959 - val_loss: 0.2601 - val_mae: 0.5399 - learning_rate: 5.0000e-04
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.1934 - mae: 0.3900 - val_loss: 0.2355 - val_mae: 0.5031 - learning_rate: 5.0000e-04
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1822 - mae: 0.3523 - val_loss: 0.2037 - val_mae: 0.4555 - learning_rate: 5.0000e-04
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.1742 - mae: 0.3482 - val_loss: 0.1978 - val_mae: 0.4475 - learning_rate: 5.0000e-04
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.1476 - mae: 0.3034 - val_loss: 0.1819 - val_mae: 0.4231 - learning_rate: 5.0000e-04
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.1399 - mae: 0.2892 - val_loss: 0.1832 - val_mae: 0.4198 - learning_rate: 5.0000e-04
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1319 - mae: 0.2703 - val_loss: 0.1726 - val_mae: 0.4047 - learning_rate: 5.0000e-04
# Epoch 9/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.1241 - mae: 0.2594 - val_loss: 0.1514 - val_mae: 0.3619 - learning_rate: 5.0000e-04
# Epoch 10/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1237 - mae: 0.2535 - val_loss: 0.1595 - val_mae: 0.3877 - learning_rate: 5.0000e-04
# Epoch 11/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1168 - mae: 0.2444 - val_loss: 0.1329 - val_mae: 0.3155 - learning_rate: 5.0000e-04
# Epoch 12/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1089 - mae: 0.2223 - val_loss: 0.1225 - val_mae: 0.2910 - learning_rate: 5.0000e-04
# Epoch 13/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0
120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.0469 - mae: 0.1173 - val_loss: 0.0363 - val_mae: 0.0330 - learning_rate: 5.0000e-04
# Epoch 86/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0458 - mae: 0.1122 - val_loss: 0.0369 - val_mae: 0.0471 - learning_rate: 5.0000e-04
# Epoch 87/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0467 - mae: 0.1178 - val_loss: 0.0370 - val_mae: 0.0517 - learning_rate: 5.0000e-04
# Epoch 88/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0475 - mae: 0.1212 - val_loss: 0.0355 - val_mae: 0.0331 - learning_rate: 5.0000e-04
# Epoch 89/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0456 - mae: 0.1150 - val_loss: 0.0357 - val_mae: 0.0377 - learning_rate: 5.0000e-04
# Epoch 90/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0439 - mae: 0.1096 - val_loss: 0.0379 - val_mae: 0.0676 - learning_rate: 5.0000e-04
# Epoch 91/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0465 - mae: 0.1216 - val_loss: 0.0372 - val_mae: 0.0636 - learning_rate: 5.0000e-04
# Epoch 92/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.0455 - mae: 0.1169 - val_loss: 0.0354 - val_mae: 0.0451 - learning_rate: 5.0000e-04
# Epoch 93/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0446 - mae: 0.1147 - val_loss: 0.0352 - val_mae: 0.0419 - learning_rate: 5.0000e-04
# Epoch 94/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0454 - mae: 0.1217 - val_loss: 0.0375 - val_mae: 0.0688 - learning_rate: 5.0000e-04
# Epoch 95/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.0471 - mae: 0.1281 - val_loss: 0.0357 - val_mae: 0.0590 - learning_rate: 5.0000e-04
# Epoch 96/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0431 - mae: 0.1083 - val_loss: 0.0345 - val_mae: 0.0443 - learning_rate: 5.0000e-04
# Epoch 97/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0489 - mae: 0.1367 - val_loss: 0.0350 - val_mae: 0.0501 - learning_rate: 5.0000e-04
# Epoch 98/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0431 - mae: 0.1117 - val_loss: 0.0359 - val_mae: 0.0688 - learning_rate: 5.0000e-04
# Epoch 99/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0443 - mae: 0.1185 - val_loss: 0.0338 - val_mae: 0.0427 - learning_rate: 5.0000e-04
# Epoch 100/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 0.0435 - mae: 0.1161 - val_loss: 0.0331 - val_mae: 0.0340 - learning_rate: 5.0000e-04
# Epoch 101/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0445 - mae: 0.1226 - val_loss: 0.0327 - val_mae: 0.0285 - learning_rate: 5.0000e-04
# Epoch 102/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0447 - mae: 0.1233 - val_loss: 0.0358 - val_mae: 0.0688 - learning_rate: 5.0000e-04
# Epoch 103/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0420 - mae: 0.1092 - val_loss: 0.0326 - val_mae: 0.0366 - learning_rate: 5.0000e-04
# Epoch 104/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0431 - mae: 0.1159 - val_loss: 0.0332 - val_mae: 0.0482 - learning_rate: 5.0000e-04
# Epoch 105/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0431 - mae: 0.1163 - val_loss: 0.0365 - val_mae: 0.0749 - learning_rate: 5.0000e-04
# Epoch 106/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0430 - mae: 0.1189 - val_loss: 0.0346 - val_mae: 0.0644 - learning_rate: 5.0000e-04
# Epoch 107/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0412 - mae: 0.1091 - val_loss: 0.0319 - val_mae: 0.0336 - learning_rate: 5.0000e-04
# Epoch 108/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.0431 - mae: 0.1192 - val_loss: 0.0319 - val_mae: 0.0363 - learning_rate: 5.0000e-04
# Epoch 109/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0414 - mae: 0.1114 - val_loss: 0.0315 - val_mae: 0.0306 - learning_rate: 5.0000e-04
# Epoch 110/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.0382 - mae: 0.0956 - val_loss: 0.0312 - val_mae: 0.0357 - learning_rate: 5.0000e-04
# Epoch 111/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0412 - mae: 0.1111 - val_loss: 0.0321 - val_mae: 0.0473 - learning_rate: 5.0000e-04
# Epoch 112/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0406 - mae: 0.1087 - val_loss: 0.0310 - val_mae: 0.0327 - learning_rate: 5.0000e-04
# Epoch 113/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0383 - mae: 0.0955 - val_loss: 0.0314 - val_mae: 0.0472 - learning_rate: 5.0000e-04
# Epoch 114/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0398 - mae: 0.1086 - val_loss: 0.0324 - val_mae: 0.0630 - learning_rate: 5.0000e-04
# Epoch 115/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0402 - mae: 0.1085 - val_loss: 0.0303 - val_mae: 0.0321 - learning_rate: 5.0000e-04
# Epoch 116/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0386 - mae: 0.1034 - val_loss: 0.0299 - val_mae: 0.0276 - learning_rate: 5.0000e-04
# Epoch 117/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.0394 - mae: 0.1096 - val_loss: 0.0320 - val_mae: 0.0543 - learning_rate: 5.0000e-04
# Epoch 118/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.0402 - mae: 0.1173 - val_loss: 0.0312 - val_mae: 0.0551 - learning_rate: 5.0000e-04
# Epoch 119/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0398 - mae: 0.1141 - val_loss: 0.0307 - val_mae: 0.0492 - learning_rate: 5.0000e-04
# Epoch 120/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0382 - mae: 0.1044 - val_loss: 0.0314 - val_mae: 0.0592 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 116.
#
# RESULTADOS FOLD
# MAE  : 41.41 m
# RMSE : 85.20 m
# R2  : 0.9905
#
# ============================================================
# FOLD 3/5
# ============================================================
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step - loss: 0.5321 - mae: 0.8199 - val_loss: 0.2223 - val_mae: 0.4802 - learning_rate: 5.0000e-04
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.3050 - mae: 0.5548 - val_loss: 0.2308 - val_mae: 0.5012 - learning_rate: 5.0000e-04
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.2637 - mae: 0.4810 - val_loss: 0.2222 - val_mae: 0.4885 - learning_rate: 5.0000e-04
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.2339 - mae: 0.4417 - val_loss: 0.1949 - val_mae: 0.4444 - learning_rate: 5.0000e-04
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.1883 - mae: 0.3692 - val_loss: 0.1839 - val_mae: 0.4221 - learning_rate: 5.0000e-04
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.1580 - mae: 0.3203 - val_loss: 0.1738 - val_mae: 0.4059 - learning_rate: 5.0000e-04
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1588 - mae: 0.3310 - val_loss: 0.1708 - val_mae: 0.4019 - learning_rate: 5.0000e-04
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.1532 - mae: 0.3094 - val_loss: 0.1662 - val_mae: 0.3911 - learning_rate: 5.0000e-04
# Epoch 9/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1403 - mae: 0.2859 - val_loss: 0.1598 - val_mae: 0.3792 - learning_rate: 5.0000e-04
# Epoch 10/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.1195 - mae: 0.2378 - val_loss: 0.1469 - val_mae: 0.3427 - learning_rate: 5.0000e-04
# Epoch 11/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1251 - mae: 0.2582 - val_loss: 0.1286 - val_mae: 0.3036 - learning_rate: 5.0000e-04
# Epoch 12/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.1196 - mae: 0.2457 - val_loss: 0.1215 - val_mae: 0.2903 - learning_rate: 5.0000e-04
# Epoch 13/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.1138 - mae: 0.2317 - val_loss: 0.1096 - val_mae: 0.2609 - learning_rate: 5.0000e-04
# Epoch 14/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.
120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0877 - mae: 0.1812 - val_loss: 0.0630 - val_mae: 0.0682 - learning_rate: 5.0000e-04
# Epoch 24/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0803 - mae: 0.1594 - val_loss: 0.0633 - val_mae: 0.0822 - learning_rate: 5.0000e-04
# Epoch 25/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0806 - mae: 0.1621 - val_loss: 0.0612 - val_mae: 0.0648 - learning_rate: 5.0000e-04
# Epoch 26/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0762 - mae: 0.1491 - val_loss: 0.0617 - val_mae: 0.0749 - learning_rate: 5.0000e-04
# Epoch 27/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0754 - mae: 0.1487 - val_loss: 0.0609 - val_mae: 0.0709 - learning_rate: 5.0000e-04
# Epoch 28/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0757 - mae: 0.1543 - val_loss: 0.0629 - val_mae: 0.0921 - learning_rate: 5.0000e-04
# Epoch 29/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0747 - mae: 0.1542 - val_loss: 0.0597 - val_mae: 0.0745 - learning_rate: 5.0000e-04
# Epoch 30/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0728 - mae: 0.1442 - val_loss: 0.0589 - val_mae: 0.0686 - learning_rate: 5.0000e-04
# Epoch 31/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0730 - mae: 0.1494 - val_loss: 0.0611 - val_mae: 0.0961 - learning_rate: 5.0000e-04
# Epoch 32/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0751 - mae: 0.1614 - val_loss: 0.0571 - val_mae: 0.0717 - learning_rate: 5.0000e-04
# Epoch 33/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0691 - mae: 0.1413 - val_loss: 0.0557 - val_mae: 0.0633 - learning_rate: 5.0000e-04
# Epoch 34/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0694 - mae: 0.1364 - val_loss: 0.0546 - val_mae: 0.0529 - learning_rate: 5.0000e-04
# Epoch 35/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0665 - mae: 0.1310 - val_loss: 0.0542 - val_mae: 0.0560 - learning_rate: 5.0000e-04
# Epoch 36/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0682 - mae: 0.1368 - val_loss: 0.0532 - val_mae: 0.0486 - learning_rate: 5.0000e-04
# Epoch 37/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0675 - mae: 0.1355 - val_loss: 0.0528 - val_mae: 0.0501 - learning_rate: 5.0000e-04
# Epoch 38/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0697 - mae: 0.1518 - val_loss: 0.0537 - val_mae: 0.0684 - learning_rate: 5.0000e-04
# Epoch 39/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0762 - mae: 0.1763 - val_loss: 0.0571 - val_mae: 0.0947 - learning_rate: 5.0000e-04
# Epoch 40/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0676 - mae: 0.1478 - val_loss: 0.0525 - val_mae: 0.0678 - learning_rate: 5.0000e-04
# Epoch 41/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0709 - mae: 0.1594 - val_loss: 0.0504 - val_mae: 0.0477 - learning_rate: 5.0000e-04
# Epoch 42/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0610 - mae: 0.1184 - val_loss: 0.0498 - val_mae: 0.0464 - learning_rate: 5.0000e-04
# Epoch 43/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0632 - mae: 0.1338 - val_loss: 0.0497 - val_mae: 0.0510 - learning_rate: 5.0000e-04
# Epoch 44/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0636 - mae: 0.1386 - val_loss: 0.0485 - val_mae: 0.0393 - learning_rate: 5.0000e-04
# Epoch 45/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0630 - mae: 0.1380 - val_loss: 0.0501 - val_mae: 0.0621 - learning_rate: 5.0000e-04
# Epoch 46/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0620 - mae: 0.1327 - val_loss: 0.0481 - val_mae: 0.0423 - learning_rate: 5.0000e-04
# Epoch 47/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0650 - mae: 0.1463 - val_loss: 0.0481 - val_mae: 0.0499 - learning_rate: 5.0000e-04
# Epoch 48/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0602 - mae: 0.1297 - val_loss: 0.0478 - val_mae: 0.0525 - learning_rate: 5.0000e-04
# Epoch 49/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0597 - mae: 0.1293 - val_loss: 0.0481 - val_mae: 0.0597 - learning_rate: 5.0000e-04
# Epoch 50/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0604 - mae: 0.1368 - val_loss: 0.0489 - val_mae: 0.0699 - learning_rate: 5.0000e-04
# Epoch 51/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0585 - mae: 0.1296 - val_loss: 0.0471 - val_mae: 0.0605 - learning_rate: 5.0000e-04
# Epoch 52/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0594 - mae: 0.1324 - val_loss: 0.0454 - val_mae: 0.0409 - learning_rate: 5.0000e-04
# Epoch 53/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0584 - mae: 0.1284 - val_loss: 0.0460 - val_mae: 0.0544 - learning_rate: 5.0000e-04
# Epoch 54/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0608 - mae: 0.1433 - val_loss: 0.0449 - val_mae: 0.0431 - learning_rate: 5.0000e-04
# Epoch 55/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0588 - mae: 0.1425 - val_loss: 0.0446 - val_mae: 0.0489 - learning_rate: 5.0000e-04
# Epoch 56/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0564 - mae: 0.1297 - val_loss: 0.0441 - val_mae: 0.0439 - learning_rate: 5.0000e-04
# Epoch 57/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0546 - mae: 0.1222 - val_loss: 0.0435 - val_mae: 0.0404 - learning_rate: 5.0000e-04
# Epoch 58/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0558 - mae: 0.1271 - val_loss: 0.0428 - val_mae: 0.0356 - learning_rate: 5.0000e-04
# Epoch 59/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0544 - mae: 0.1169 - val_loss: 0.0435 - val_mae: 0.0463 - learning_rate: 5.0000e-04
# Epoch 60/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0543 - mae: 0.1222 - val_loss: 0.0429 - val_mae: 0.0497 - learning_rate: 5.0000e-04
# Epoch 61/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0525 - mae: 0.1170 - val_loss: 0.0433 - val_mae: 0.0534 - learning_rate: 5.0000e-04
# Epoch 62/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0528 - mae: 0.1236 - val_loss: 0.0424 - val_mae: 0.0509 - learning_rate: 5.0000e-04
# Epoch 63/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0516 - mae: 0.1152 - val_loss: 0.0426 - val_mae: 0.0546 - learning_rate: 5.0000e-04
# Epoch 64/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0535 - mae: 0.1258 - val_loss: 0.0412 - val_mae: 0.0433 - learning_rate: 5.0000e-04
# Epoch 65/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0527 - mae: 0.1212 - val_loss: 0.0418 - val_mae: 0.0514 - learning_rate: 5.0000e-04
# Epoch 66/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0526 - mae: 0.1168 - val_loss: 0.0405 - val_mae: 0.0399 - learning_rate: 5.0000e-04
# Epoch 67/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0496 - mae: 0.1168 - val_loss: 0.0411 - val_mae: 0.0497 - learning_rate: 5.0000e-04
# Epoch 68/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0504 - mae: 0.1155 - val_loss: 0.0410 - val_mae: 0.0531 - learning_rate: 5.0000e-04
# Epoch 69/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0494 - mae: 0.1134 - val_loss: 0.0416 - val_mae: 0.0615 - learning_rate: 5.0000e-04
# Epoch 70/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0508 - mae: 0.1240 - val_loss: 0.0395 - val_mae: 0.0438 - learning_rate: 5.0000e-04
# Epoch 71/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0514 - mae: 0.1288 - val_loss: 0.0390 - val_mae: 0.0406 - learning_rate: 5.0000e-04
# Epoch 72/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0487 - mae: 0.1120 - val_loss: 0.0410 - val_mae: 0.0706 - learning_rate: 5.0000e-04
# Epoch 73/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0495 - mae: 0.1157 - val_loss: 0.0430 - val_mae: 0.0777 - learning_rate: 5.0000e-04
# Epoch 74/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0479 - mae: 0.1135 - val_loss: 0.0397 - val_mae: 0.0618 - learning_rate: 5.0000e-04
# Epoch 75/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0510 - mae: 0.1275 - val_loss: 0.0416 - val_mae: 0.0811 - learning_rate: 5.0000e-04
# Epoch 76/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0480 - mae: 0.1176 - val_loss: 0.0378 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 77/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0475 - mae: 0.1156 - val_loss: 0.0377 - val_mae: 0.0460 - learning_rate: 5.0000e-04
# Epoch 78/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0463 - mae: 0.1117 - val_loss: 0.0368 - val_mae: 0.0332 - learning_rate: 5.0000e-04
# Epoch 79/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0465 - mae: 0.1145 - val_loss: 0.0384 - val_mae: 0.0571 - learning_rate: 5.0000e-04
# Epoch 80/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0486 - mae: 0.1239 - val_loss: 0.0379 - val_mae: 0.0587 - learning_rate: 5.0000e-04
# Epoch 81/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0456 - mae: 0.1111 - val_loss: 0.0359 - val_mae: 0.0292 - learning_rate: 5.0000e-04
# Epoch 82/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0475 - mae: 0.1172 - val_loss: 0.0357 - val_mae: 0.0323 - learning_rate: 5.0000e-04
# Epoch 83/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0454 - mae: 0.1112 - val_loss: 0.0359 - val_mae: 0.0375 - learning_rate: 5.0000e-04
# Epoch 84/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0479 - mae: 0.1287 - val_loss: 0.0371 - val_mae: 0.0598 - learning_rate: 5.0000e-04
# Epoch 85/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0457 - mae: 0.1151 - val_loss: 0.0359 - val_mae: 0.0472 - learning_rate: 5.0000e-04
# Epoch 86/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0440 - mae: 0.1032 - val_loss: 0.0354 - val_mae: 0.0453 - learning_rate: 5.0000e-04
# Epoch 87/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0452 - mae: 0.1144 - val_loss: 0.0346 - val_mae: 0.0309 - learning_rate: 5.0000e-04
# Epoch 88/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0452 - mae: 0.1196 - val_loss: 0.0363 - val_mae: 0.0571 - learning_rate: 5.0000e-04
# Epoch 89/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0452 - mae: 0.1140 - val_loss: 0.0349 - val_mae: 0.0466 - learning_rate: 5.0000e-04
# Epoch 90/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0435 - mae: 0.1097 - val_loss: 0.0348 - val_mae: 0.0462 - learning_rate: 5.0000e-04
# Epoch 91/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0437 - mae: 0.1135 - val_loss: 0.0345 - val_mae: 0.0468 - learning_rate: 5.0000e-04
# Epoch 92/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0450 - mae: 0.1255 - val_loss: 0.0359 - val_mae: 0.0676 - learning_rate: 5.0000e-04
# Epoch 93/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0434 - mae: 0.1144 - val_loss: 0.0353 - val_mae: 0.0624 - learning_rate: 5.0000e-04
# Epoch 94/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0428 - mae: 0.1117 - val_loss: 0.0336 - val_mae: 0.0370 - learning_rate: 5.0000e-04
# Epoch 95/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0442 - mae: 0.1229 - val_loss: 0.0349 - val_mae: 0.0626 - learning_rate: 5.0000e-04
# Epoch 96/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0433 - mae: 0.1149 - val_loss: 0.0338 - val_mae: 0.0485 - learning_rate: 5.0000e-04
# Epoch 97/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0432 - mae: 0.1201 - val_loss: 0.0328 - val_mae: 0.0372 - learning_rate: 5.0000e-04
# Epoch 98/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0432 - mae: 0.1130 - val_loss: 0.0329 - val_mae: 0.0409 - learning_rate: 5.0000e-04
# Epoch 99/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0430 - mae: 0.1176 - val_loss: 0.0322 - val_mae: 0.0331 - learning_rate: 5.0000e-04
# Epoch 100/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0398 - mae: 0.0992 - val_loss: 0.0323 - val_mae: 0.0398 - learning_rate: 5.0000e-04
# Epoch 101/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0418 - mae: 0.1096 - val_loss: 0.0318 - val_mae: 0.0340 - learning_rate: 5.0000e-04
# Epoch 102/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0416 - mae: 0.1155 - val_loss: 0.0317 - val_mae: 0.0342 - learning_rate: 5.0000e-04
# Epoch 103/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0394 - mae: 0.1041 - val_loss: 0.0314 - val_mae: 0.0329 - learning_rate: 5.0000e-04
# Epoch 104/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0410 - mae: 0.1062 - val_loss: 0.0313 - val_mae: 0.0331 - learning_rate: 5.0000e-04
# Epoch 105/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0393 - mae: 0.1002 - val_loss: 0.0314 - val_mae: 0.0368 - learning_rate: 5.0000e-04
# Epoch 106/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0386 - mae: 0.1013 - val_loss: 0.0320 - val_mae: 0.0498 - learning_rate: 5.0000e-04
# Epoch 107/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0403 - mae: 0.1094 - val_loss: 0.0310 - val_mae: 0.0379 - learning_rate: 5.0000e-04
# Epoch 108/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0387 - mae: 0.1022 - val_loss: 0.0305 - val_mae: 0.0328 - learning_rate: 5.0000e-04
# Epoch 109/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0403 - mae: 0.1083 - val_loss: 0.0310 - val_mae: 0.0445 - learning_rate: 5.0000e-04
# Epoch 110/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0381 - mae: 0.0995 - val_loss: 0.0304 - val_mae: 0.0379 - learning_rate: 5.0000e-04
# Epoch 111/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0373 - mae: 0.0980 - val_loss: 0.0306 - val_mae: 0.0430 - learning_rate: 5.0000e-04
# Epoch 112/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0382 - mae: 0.0984 - val_loss: 0.0298 - val_mae: 0.0338 - learning_rate: 5.0000e-04
# Epoch 113/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0371 - mae: 0.0992 - val_loss: 0.0300 - val_mae: 0.0406 - learning_rate: 5.0000e-04
# Epoch 114/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0386 - mae: 0.1081 - val_loss: 0.0293 - val_mae: 0.0287 - learning_rate: 5.0000e-04
# Epoch 115/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0375 - mae: 0.1001 - val_loss: 0.0296 - val_mae: 0.0370 - learning_rate: 5.0000e-04
# Epoch 116/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0375 - mae: 0.1011 - val_loss: 0.0312 - val_mae: 0.0632 - learning_rate: 5.0000e-04
# Epoch 117/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0378 - mae: 0.1056 - val_loss: 0.0301 - val_mae: 0.0518 - learning_rate: 5.0000e-04
# Epoch 118/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0406 - mae: 0.1200 - val_loss: 0.0319 - val_mae: 0.0747 - learning_rate: 5.0000e-04
# Epoch 119/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0378 - mae: 0.1104 - val_loss: 0.0287 - val_mae: 0.0353 - learning_rate: 5.0000e-04
# Epoch 120/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0381 - mae: 0.1081 - val_loss: 0.0286 - val_mae: 0.0361 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 120.
#
# RESULTADOS FOLD
# MAE  : 40.63 m
# RMSE : 70.65 m
# R2  : 0.9935
#
#
# ============================================================
# RESUMEN LSTM V10
# ============================================================
# MAE  : 47.75 ± 7.27 m
# RMSE : 86.08 ± 12.36 m
# R2   : 0.9902
# ============================================================
