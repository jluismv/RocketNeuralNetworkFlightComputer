# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    GRU,
    Bidirectional,
    GaussianNoise,
    BatchNormalization,
    Conv1D,
    MaxPooling1D
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber
# 1. CONFIGURACIÓN
PROCESSED_PATH = Path(r"C:\TensorFlow\RocketNeuralNetworkFlightComputer\Data\Processed Data\Augmented")
WINDOW_SIZE = 201
FEATURES_LSTM = ["baro_altitude","accl_x","accl_y","accl_z","At","P"]
# 2. LOCALIZAR ARCHIVOS
archivos_originales = list(PROCESSED_PATH.glob("*.csv"))
print("EXTRACCIÓN DE DATOS")
print("Ruta:")
print(PROCESSED_PATH)
print(f"\nArchivos CSV encontrados: {len(archivos_originales)}")
if len(archivos_originales) == 0:

    raise ValueError( "\nNO SE ENCONTRARON ARCHIVOS CSV.\n""Revisa que la ruta sea exactamente:\n"r"C:\TensorFlow\RocketNeuralNetworkFlightComputer\Data\Processed Data\Augmented")

# 3. EXTRACCIÓN DE SECUENCIAS
X_seq = []
y_seq = []
base_ids = []
archivos_procesados = 0
archivos_descartados_altura = 0
archivos_sin_despegue = 0
archivos_ventana_corta = 0

for archivo in archivos_originales:
    try:
        df = pd.read_csv(archivo)
        df.columns = df.columns.str.strip()
        columnas_necesarias = [ "time","baro_altitude", "accl_x","accl_y","accl_z"]
        faltantes = [c for c in columnas_necesarias if c not in df.columns ]
        if len(faltantes) > 0:
            print(
                f"\nDescartado {archivo.name}"
                f" -> faltan columnas: {faltantes}"
            )

            continue
        # Orden temporal
        df = df.sort_values("time").reset_index(drop=True)
        # Eliminar NaN en variables principales
        df = df.dropna(
            subset=["baro_altitude","accl_x","accl_y","accl_z" ]).reset_index(drop=True)

        if len(df) == 0:
            continue
        # RECONSTRUCCIÓN DE CARACTERÍSTICAS
        # Aceleración total
        if "At" not in df.columns:
            df["At"] = np.sqrt(
                df["accl_x"]**2 +
                df["accl_y"]**2 +
                df["accl_z"]**2
            )
        # Presión atmosférica
        if "P" not in df.columns:
            df["P"] = (101325.0 *(1 - 2.25577e-5 * df["baro_altitude"])**5.25588 )
        # Eliminar valores no válidos
        df = df.replace([np.inf, -np.inf],np.nan)
        df = df.dropna(
            subset=FEATURES_LSTM
        ).reset_index(drop=True)
        if len(df) == 0:
            continue
        # APOGEO REAL
        apogeo_real = float(
            df["baro_altitude"].max()
        )
        # Filtro físico
        if apogeo_real > 4500:
            archivos_descartados_altura += 1
            continue
        # Evitar objetivos absurdos o negativos
        if apogeo_real <= 0:
            continue
        # TRIGGER DE DESPEGUE
        despegues = df.index[df["At"] > 15]
        if len(despegues) == 0:
            archivos_sin_despegue += 1
            continue
        idx_despegue = int(
            despegues[0]
        )
        # EXTRAER VENTANA
        window = df.iloc[
            idx_despegue:
            idx_despegue + WINDOW_SIZE
        ]
        if len(window) != WINDOW_SIZE:
            archivos_ventana_corta += 1
            continue
        # GUARDAR
        X_seq.append(
            window[FEATURES_LSTM].values
        )
        y_seq.append(
            apogeo_real
        )
        base_ids.append(
            archivo.stem
        )
        archivos_procesados += 1
    except Exception as e:
        print(
            f"\nError procesando {archivo.name}: {e}"
        )
# 4. CONVERTIR A NUMPY
X_temporal = np.array(
    X_seq,
    dtype=np.float32
)
y_temporal = np.array(
    y_seq,
    dtype=np.float32
)
flight_ids_temporal = np.array(
    base_ids
)
# 5. DIAGNÓSTICO DE DATOS
print("DIAGNÓSTICO DE DATOS")
print(f"Archivos originales       : {len(archivos_originales)}")
print(f"Archivos procesados       : {archivos_procesados}")
print(f"Descartados por >4500 m   : "f"{archivos_descartados_altura}")
print(f"Sin trigger de despegue   : "f"{archivos_sin_despegue}")
print(f"Ventana insuficiente      : "f"{archivos_ventana_corta}")
print(f"\nX_temporal: {X_temporal.shape}")
print(f"y_temporal: {y_temporal.shape}")
print(f"Vuelos únicos: "f"{len(np.unique(flight_ids_temporal))}")
# 6. PROTECCIÓN CONTRA DATASET VACÍO
if len(X_temporal) == 0:

    raise ValueError(
        "\nERROR: X_temporal está vacío.\n\n"
        "El problema está en la extracción de los CSV, "
        "no en la red neuronal.\n\n"
        "Revisa principalmente:\n"
        "1. La ruta.\n"
        "2. Las columnas de los CSV.\n"
        "3. El trigger At > 15.\n"
        "4. Que existan al menos 201 muestras después del despegue."
    )
# 7. TRANSFORMACIÓN DEL OBJETIVO
y_temporal_log = np.log1p(y_temporal)
# 8. GRUPOS POR VUELO
unique_base_ids = np.unique(flight_ids_temporal)

if len(unique_base_ids) < 3:
    print("\n⚠️ Menos de 3 vuelos.")
    grupos_kfold = np.arange(len(X_temporal))
else:
    grupos_kfold = flight_ids_temporal
# 9. MODELO V9
def build_lstm_v9(input_shape):

    model = Sequential(name="LSTM_V9")
    model.add(Input(shape=input_shape))
    # Ruido ligero
    model.add(GaussianNoise(0.01))
    # Extracción de características temporales
    model.add(
        Conv1D(
            filters=64,
            kernel_size=3,
            activation="relu",
            padding="same"
        )
    )
    model.add(BatchNormalization() )
    model.add(MaxPooling1D(pool_size=2))
    model.add(Bidirectional(GRU(96,return_sequences=False,dropout=0.2,kernel_regularizer=l2(0.0005) )))
    model.add(BatchNormalization())
    model.add(Dense(32,activation="relu",kernel_regularizer=l2(0.0005)))
    model.add(Dropout( 0.15 ))
    model.add( Dense(1))
    # Optimizador
    optimizer = tf.keras.optimizers.AdamW(
        learning_rate=5e-4,
        weight_decay=1e-4,
        clipnorm=1.0
    )
    model.compile(
        optimizer=optimizer,
        loss=Huber(),
        metrics=["mae"]
    )
    return model
# 10. VALIDACIÓN GROUP K-FOLD
def groupkfold_evaluate_lstm(build_fn,X,y,groups,n_splits=5,epochs=120,batch_size=32,patience=20):
    n_splits = min(n_splits,len(np.unique(groups)))
    gkf = GroupKFold(n_splits=n_splits)
    fold_metrics = []
    for fold, (train_idx, val_idx) in enumerate(
        gkf.split(X,y,groups)):
        tf.keras.backend.clear_session()
        print("\n" + "=" * 60)
        print(
            f"FOLD {fold + 1}/{n_splits}"
        )
        print("=" * 60)
        # DATOS DEL FOLD
        X_train_f = X[train_idx]
        X_val_f = X[val_idx]
        y_train_f = y[ train_idx]
        y_val_f = y[val_idx]
        # ESCALADO X
        n_features = X_train_f.shape[2]
        scaler_X = StandardScaler()
        X_train_scaled = scaler_X.fit_transform(
            X_train_f.reshape(
                -1,
                n_features
            )
        ).reshape(
            X_train_f.shape
        )
        X_val_scaled = scaler_X.transform(
            X_val_f.reshape(
                -1,
                n_features
            )
        ).reshape(
            X_val_f.shape
        )
        # ESCALADO Y
        scaler_y = RobustScaler()
        y_train_scaled = scaler_y.fit_transform(
            y_train_f.reshape(
                -1,
                1
            )
        ).ravel()
        y_val_scaled = scaler_y.transform(
            y_val_f.reshape(
                -1,
                1
            )
        ).ravel()
        # CREAR MODELO
        model = build_fn(
            input_shape=(
                X_train_scaled.shape[1],
                X_train_scaled.shape[2]
            )
        )
        # CALLBACKS
        early_stop = tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=patience,
            restore_best_weights=True,
            verbose=1
        )
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=8,
            min_lr=1e-5,
            verbose=1
        )
        # ENTRENAMIENTO
        history = model.fit(
            X_train_scaled,
            y_train_scaled,
            validation_data=(
                X_val_scaled,
                y_val_scaled
            ),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=[
                early_stop,
                reduce_lr
            ],
            verbose=1
        )
        # PREDICCIÓN
        preds_scaled = model.predict(
            X_val_scaled,
            verbose=0
        ).ravel()
        # DESHACER ESCALADO
        y_pred_log = scaler_y.inverse_transform(
            preds_scaled.reshape(
                -1,
                1
            )
        ).ravel()
        # VOLVER A METROS
        y_pred_metros = np.expm1(y_pred_log)
        y_true_metros = np.expm1(y_val_f)
        # Evitar predicciones negativas
        y_pred_metros = np.maximum(y_pred_metros,0)
        # MÉTRICAS
        mae = mean_absolute_error(
y_true_metros,
            y_pred_metros
        )
        rmse = np.sqrt(
            mean_squared_error(
                y_true_metros,
                y_pred_metros
            )
        )
        r2 = r2_score(
            y_true_metros,
            y_pred_metros
        )
        print("\nRESULTADOS FOLD")
        print(f"MAE  : {mae:.2f} m")
        print( f"RMSE : {rmse:.2f} m")
        print( f"R2  : {r2:.4f}")
        fold_metrics.append(
            {"MAE": mae,"RMSE": rmse,"R2": r2,"y_true": y_true_metros,"y_pred": y_pred_metros,"history": history })
    return fold_metrics
# 11. RESUMEN
def summarize_cv(fold_metrics,name):
    maes = [m["MAE"]for m in fold_metrics]
    rmses = [m["RMSE"]for m in fold_metrics]
    r2s = [m["R2"]for m in fold_metrics]
    print("\n")
    print("=" * 60)
    print(
        f"RESUMEN {name}"
    )
    print("=" * 60)
    print(f"MAE  : "f"{np.mean(maes):.2f} "f"± {np.std(maes):.2f} m")
    print(f"RMSE : "f"{np.mean(rmses):.2f} "f"± {np.std(rmses):.2f} m")
    print( f"R2   : "f"{np.mean(r2s):.4f}")
    print("=" * 60)
# 12. GRÁFICAS
def plot_kfold_diagnostics(fold_metrics):
    n_folds = len(fold_metrics)
    fig, axes = plt.subplots(
        1,
        n_folds,
        figsize=(
            4.5 * n_folds,
            5
        ),
        sharey=True
    )
    if n_folds == 1:
        axes = [axes]
    for i, ax in enumerate(axes):
        y_true = fold_metrics[i]["y_true"]
        y_pred = fold_metrics[i]["y_pred"]
        r2 = fold_metrics[i][ "R2"]
        ax.scatter(y_true,y_pred,alpha=0.7,c="#1f77b4",edgecolors="k")
        min_val = min(np.min(y_true),np.min(y_pred))
        max_val = max(np.max(y_true),np.max(y_pred))
        ax.plot([min_val, max_val],[min_val, max_val],"r--",lw=2,label="Predicción ideal")
        ax.axvline(3000,color="green",linestyle=":",lw=2,label="Meta 3000 m")
        ax.axhline(3000,color="green",linestyle=":",lw=2)
        ax.set_title(f"Fold {i + 1} | R² = {r2:.2f}")
        ax.set_xlabel("Apogeo real (m)")
        if i == 0:
            ax.set_ylabel("Apogeo predicho (m)")
            ax.legend()
        ax.grid( True,linestyle="--",alpha=0.7)
    plt.suptitle("LSTM V9  Auditoría de Vuelos",fontsize=14,y=1.05)
    plt.tight_layout()
    plt.show()
# 13. EJECUCIÓN
print("\n")
print("=" * 60)
print("INICIANDO LSTM V8 MEJORADA")
print("=" * 60)
print(f"Dataset: {X_temporal.shape}")
print(f"Ventana: {WINDOW_SIZE}")
print(f"Características: {len(FEATURES_LSTM)}")
print(f"Vuelos: {len(unique_base_ids)}")

cv_lstm_v9_folds = groupkfold_evaluate_lstm(
    build_fn=build_lstm_v9,
    X=X_temporal,
    y=y_temporal_log,
    groups=grupos_kfold,
    n_splits=5,
    epochs=120,
    batch_size=32,
    patience=20
)
# 14. RESULTADOS
summarize_cv(
    cv_lstm_v9_folds,
    "LSTM V9 MEJORADA"
)
# 15. GRÁFICAS
plot_kfold_diagnostics(
    cv_lstm_v9_folds
)
# Out:
# EXTRACCIÓN DE DATOS
# Ruta:
# C:\TensorFlow\RocketNeuralNetworkFlightComputer\Data\Processed Data\Augmented
#
# Archivos CSV encontrados: 620
# DIAGNÓSTICO DE DATOS
# Archivos originales       : 620
# Archivos procesados       : 580
# Descartados por >4500 m   : 30
# Sin trigger de despegue   : 0
# Ventana insuficiente      : 10
#
# X_temporal: (580, 201, 6)
# y_temporal: (580,)
# Vuelos únicos: 580
#
#
# ============================================================
# INICIANDO LSTM V8 MEJORADA
# ============================================================
# Dataset: (580, 201, 6)
# Ventana: 201
# Características: 6
# Vuelos: 580
# WARNING:tensorflow:From c:\Users\JoLui\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#
# ============================================================
# FOLD 1/5
# ============================================================
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 142ms/step - loss: 0.4286 - mae: 0.6334 - val_loss: 0.2588 - val_mae: 0.4496 - learning_rate: 5.0000e-04
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3310 - mae: 0.5110 - val_loss: 0.2509 - val_mae: 0.4422 - learning_rate: 5.0000e-04
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.3020 - mae: 0.4623 - val_loss: 0.2432 - val_mae: 0.4282 - learning_rate: 5.0000e-04
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2652 - mae: 0.4078 - val_loss: 0.2441 - val_mae: 0.4350 - learning_rate: 5.0000e-04
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2419 - mae: 0.3846 - val_loss: 0.2381 - val_mae: 0.4280 - learning_rate: 5.0000e-04
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.2351 - mae: 0.3735 - val_loss: 0.2221 - val_mae: 0.3924 - learning_rate: 5.0000e-04
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2130 - mae: 0.3337 - val_loss: 0.2355 - val_mae: 0.4249 - learning_rate: 5.0000e-04
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.
120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0655 - mae: 0.1010 - val_loss: 0.0578 - val_mae: 0.0418 - learning_rate: 5.0000e-04
# Epoch 82/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0665 - mae: 0.1111 - val_loss: 0.0581 - val_mae: 0.0501 - learning_rate: 5.0000e-04
# Epoch 83/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0703 - mae: 0.1377 - val_loss: 0.0567 - val_mae: 0.0389 - learning_rate: 5.0000e-04
# Epoch 84/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0662 - mae: 0.1136 - val_loss: 0.0558 - val_mae: 0.0307 - learning_rate: 5.0000e-04
# Epoch 85/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0649 - mae: 0.1119 - val_loss: 0.0555 - val_mae: 0.0323 - learning_rate: 5.0000e-04
# Epoch 86/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0633 - mae: 0.1055 - val_loss: 0.0559 - val_mae: 0.0424 - learning_rate: 5.0000e-04
# Epoch 87/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0648 - mae: 0.1157 - val_loss: 0.0548 - val_mae: 0.0358 - learning_rate: 5.0000e-04
# Epoch 88/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0638 - mae: 0.1124 - val_loss: 0.0552 - val_mae: 0.0434 - learning_rate: 5.0000e-04
# Epoch 89/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0644 - mae: 0.1197 - val_loss: 0.0538 - val_mae: 0.0339 - learning_rate: 5.0000e-04
# Epoch 90/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0670 - mae: 0.1349 - val_loss: 0.0538 - val_mae: 0.0377 - learning_rate: 5.0000e-04
# Epoch 91/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0627 - mae: 0.1116 - val_loss: 0.0528 - val_mae: 0.0346 - learning_rate: 5.0000e-04
# Epoch 92/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0632 - mae: 0.1184 - val_loss: 0.0527 - val_mae: 0.0396 - learning_rate: 5.0000e-04
# Epoch 93/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0636 - mae: 0.1227 - val_loss: 0.0523 - val_mae: 0.0375 - learning_rate: 5.0000e-04
# Epoch 94/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0618 - mae: 0.1131 - val_loss: 0.0518 - val_mae: 0.0385 - learning_rate: 5.0000e-04
# Epoch 95/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0620 - mae: 0.1159 - val_loss: 0.0513 - val_mae: 0.0350 - learning_rate: 5.0000e-04
# Epoch 96/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0615 - mae: 0.1153 - val_loss: 0.0508 - val_mae: 0.0336 - learning_rate: 5.0000e-04
# Epoch 97/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0590 - mae: 0.1078 - val_loss: 0.0503 - val_mae: 0.0321 - learning_rate: 5.0000e-04
# Epoch 98/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0601 - mae: 0.1134 - val_loss: 0.0512 - val_mae: 0.0483 - learning_rate: 5.0000e-04
# Epoch 99/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0597 - mae: 0.1142 - val_loss: 0.0495 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 100/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0583 - mae: 0.1099 - val_loss: 0.0489 - val_mae: 0.0308 - learning_rate: 5.0000e-04
# Epoch 101/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0575 - mae: 0.1066 - val_loss: 0.0489 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 102/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0572 - mae: 0.1081 - val_loss: 0.0480 - val_mae: 0.0278 - learning_rate: 5.0000e-04
# Epoch 103/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0575 - mae: 0.1121 - val_loss: 0.0476 - val_mae: 0.0277 - learning_rate: 5.0000e-04
# Epoch 104/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0560 - mae: 0.1039 - val_loss: 0.0473 - val_mae: 0.0300 - learning_rate: 5.0000e-04
# Epoch 105/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0541 - mae: 0.0958 - val_loss: 0.0475 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 106/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0543 - mae: 0.1003 - val_loss: 0.0467 - val_mae: 0.0306 - learning_rate: 5.0000e-04
# Epoch 107/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0549 - mae: 0.1084 - val_loss: 0.0466 - val_mae: 0.0359 - learning_rate: 5.0000e-04
# Epoch 108/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0555 - mae: 0.1106 - val_loss: 0.0459 - val_mae: 0.0311 - learning_rate: 5.0000e-04
# Epoch 109/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0571 - mae: 0.1198 - val_loss: 0.0485 - val_mae: 0.0634 - learning_rate: 5.0000e-04
# Epoch 110/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0557 - mae: 0.1175 - val_loss: 0.0455 - val_mae: 0.0369 - learning_rate: 5.0000e-04
# Epoch 111/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0534 - mae: 0.1025 - val_loss: 0.0447 - val_mae: 0.0285 - learning_rate: 5.0000e-04
# Epoch 112/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0527 - mae: 0.1064 - val_loss: 0.0446 - val_mae: 0.0355 - learning_rate: 5.0000e-04
# Epoch 113/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0540 - mae: 0.1106 - val_loss: 0.0443 - val_mae: 0.0340 - learning_rate: 5.0000e-04
# Epoch 114/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0521 - mae: 0.1010 - val_loss: 0.0435 - val_mae: 0.0270 - learning_rate: 5.0000e-04
# Epoch 115/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0522 - mae: 0.1060 - val_loss: 0.0444 - val_mae: 0.0420 - learning_rate: 5.0000e-04
# Epoch 116/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0521 - mae: 0.1072 - val_loss: 0.0435 - val_mae: 0.0354 - learning_rate: 5.0000e-04
# Epoch 117/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0513 - mae: 0.1038 - val_loss: 0.0433 - val_mae: 0.0381 - learning_rate: 5.0000e-04
# Epoch 118/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0511 - mae: 0.1051 - val_loss: 0.0424 - val_mae: 0.0310 - learning_rate: 5.0000e-04
# Epoch 119/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0493 - mae: 0.0965 - val_loss: 0.0420 - val_mae: 0.0295 - learning_rate: 5.0000e-04
# Epoch 120/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0504 - mae: 0.1070 - val_loss: 0.0426 - val_mae: 0.0402 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 119.
#
# RESULTADOS FOLD
# MAE  : 45.77 m
# RMSE : 107.17 m
# R2  : 0.9852
#
# ============================================================
# FOLD 2/5
# ============================================================
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 0.5416 - mae: 0.7751 - val_loss: 0.2903 - val_mae: 0.4980 - learning_rate: 5.0000e-04
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4396 - mae: 0.6544 - val_loss: 0.2502 - val_mae: 0.4143 - learning_rate: 5.0000e-04
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.3368 - mae: 0.5169 - val_loss: 0.2682 - val_mae: 0.4515 - learning_rate: 5.0000e-04
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3169 - mae: 0.4956 - val_loss: 0.2414 - val_mae: 0.3957 - learning_rate: 5.0000e-04
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.2943 - mae: 0.4602 - val_loss: 0.2218 - val_mae: 0.3605 - learning_rate: 5.0000e-04
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2788 - mae: 0.4386 - val_loss: 0.2335 - val_mae: 0.3980 - learning_rate: 5.0000e-04
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2503 - mae: 0.3911 - val_loss: 0.2251 - val_mae: 0.3747 - learning_rate: 5.0000e-04
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2364 - mae: 0.3702 - val_loss: 0.1979 - val_mae: 0.3172 - learning_rate: 5.0000e-04
# Epoch 9/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2233 - mae: 0.3521 - val_loss: 0.1963 - val_mae: 0.3270 - learning_rate: 5.0000e-04
# Epoch 10/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0
120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0739 - mae: 0.1286 - val_loss: 0.0623 - val_mae: 0.0426 - learning_rate: 5.0000e-04
# Epoch 84/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0733 - mae: 0.1251 - val_loss: 0.0611 - val_mae: 0.0373 - learning_rate: 5.0000e-04
# Epoch 85/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0735 - mae: 0.1249 - val_loss: 0.0606 - val_mae: 0.0338 - learning_rate: 5.0000e-04
# Epoch 86/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0721 - mae: 0.1238 - val_loss: 0.0606 - val_mae: 0.0419 - learning_rate: 5.0000e-04
# Epoch 87/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0709 - mae: 0.1236 - val_loss: 0.0600 - val_mae: 0.0403 - learning_rate: 5.0000e-04
# Epoch 88/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0712 - mae: 0.1255 - val_loss: 0.0589 - val_mae: 0.0275 - learning_rate: 5.0000e-04
# Epoch 89/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0716 - mae: 0.1306 - val_loss: 0.0595 - val_mae: 0.0426 - learning_rate: 5.0000e-04
# Epoch 90/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0696 - mae: 0.1210 - val_loss: 0.0589 - val_mae: 0.0426 - learning_rate: 5.0000e-04
# Epoch 91/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0676 - mae: 0.1097 - val_loss: 0.0586 - val_mae: 0.0419 - learning_rate: 5.0000e-04
# Epoch 92/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0691 - mae: 0.1214 - val_loss: 0.0577 - val_mae: 0.0380 - learning_rate: 5.0000e-04
# Epoch 93/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0686 - mae: 0.1184 - val_loss: 0.0573 - val_mae: 0.0344 - learning_rate: 5.0000e-04
# Epoch 94/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0661 - mae: 0.1124 - val_loss: 0.0569 - val_mae: 0.0376 - learning_rate: 5.0000e-04
# Epoch 95/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0672 - mae: 0.1186 - val_loss: 0.0567 - val_mae: 0.0418 - learning_rate: 5.0000e-04
# Epoch 96/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0657 - mae: 0.1116 - val_loss: 0.0569 - val_mae: 0.0475 - learning_rate: 5.0000e-04
# Epoch 97/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0675 - mae: 0.1266 - val_loss: 0.0569 - val_mae: 0.0565 - learning_rate: 5.0000e-04
# Epoch 98/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0667 - mae: 0.1229 - val_loss: 0.0557 - val_mae: 0.0414 - learning_rate: 5.0000e-04
# Epoch 99/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0671 - mae: 0.1238 - val_loss: 0.0553 - val_mae: 0.0440 - learning_rate: 5.0000e-04
# Epoch 100/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0654 - mae: 0.1179 - val_loss: 0.0550 - val_mae: 0.0442 - learning_rate: 5.0000e-04
# Epoch 101/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0648 - mae: 0.1191 - val_loss: 0.0545 - val_mae: 0.0458 - learning_rate: 5.0000e-04
# Epoch 102/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0626 - mae: 0.1072 - val_loss: 0.0539 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 103/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0630 - mae: 0.1142 - val_loss: 0.0541 - val_mae: 0.0464 - learning_rate: 5.0000e-04
# Epoch 104/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0639 - mae: 0.1203 - val_loss: 0.0537 - val_mae: 0.0466 - learning_rate: 5.0000e-04
# Epoch 105/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0680 - mae: 0.1399 - val_loss: 0.0546 - val_mae: 0.0607 - learning_rate: 5.0000e-04
# Epoch 106/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0629 - mae: 0.1203 - val_loss: 0.0526 - val_mae: 0.0438 - learning_rate: 5.0000e-04
# Epoch 107/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0623 - mae: 0.1146 - val_loss: 0.0536 - val_mae: 0.0506 - learning_rate: 5.0000e-04
# Epoch 108/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0613 - mae: 0.1137 - val_loss: 0.0518 - val_mae: 0.0413 - learning_rate: 5.0000e-04
# Epoch 109/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0603 - mae: 0.1123 - val_loss: 0.0512 - val_mae: 0.0397 - learning_rate: 5.0000e-04
# Epoch 110/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0593 - mae: 0.1035 - val_loss: 0.0516 - val_mae: 0.0470 - learning_rate: 5.0000e-04
# Epoch 111/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0598 - mae: 0.1102 - val_loss: 0.0501 - val_mae: 0.0337 - learning_rate: 5.0000e-04
# Epoch 112/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0599 - mae: 0.1151 - val_loss: 0.0501 - val_mae: 0.0385 - learning_rate: 5.0000e-04
# Epoch 113/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0588 - mae: 0.1127 - val_loss: 0.0507 - val_mae: 0.0490 - learning_rate: 5.0000e-04
# Epoch 114/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0584 - mae: 0.1096 - val_loss: 0.0491 - val_mae: 0.0319 - learning_rate: 5.0000e-04
# Epoch 115/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0602 - mae: 0.1208 - val_loss: 0.0496 - val_mae: 0.0436 - learning_rate: 5.0000e-04
# Epoch 116/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0606 - mae: 0.1267 - val_loss: 0.0485 - val_mae: 0.0364 - learning_rate: 5.0000e-04
# Epoch 117/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0576 - mae: 0.1107 - val_loss: 0.0479 - val_mae: 0.0301 - learning_rate: 5.0000e-04
# Epoch 118/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0581 - mae: 0.1138 - val_loss: 0.0487 - val_mae: 0.0491 - learning_rate: 5.0000e-04
# Epoch 119/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0568 - mae: 0.1095 - val_loss: 0.0477 - val_mae: 0.0329 - learning_rate: 5.0000e-04
# Epoch 120/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0572 - mae: 0.1164 - val_loss: 0.0471 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 120.
#
# RESULTADOS FOLD
# MAE  : 51.91 m
# RMSE : 103.24 m
# R2  : 0.9860
#
# ============================================================
# FOLD 3/5
# ============================================================
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step - loss: 0.5361 - mae: 0.7672 - val_loss: 0.3051 - val_mae: 0.5212 - learning_rate: 5.0000e-04
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4222 - mae: 0.6185 - val_loss: 0.2578 - val_mae: 0.4458 - learning_rate: 5.0000e-04
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.3391 - mae: 0.5088 - val_loss: 0.2676 - val_mae: 0.4636 - learning_rate: 5.0000e-04
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3027 - mae: 0.4627 - val_loss: 0.2458 - val_mae: 0.4185 - learning_rate: 5.0000e-04
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.2648 - mae: 0.4011 - val_loss: 0.2249 - val_mae: 0.3825 - learning_rate: 5.0000e-04
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2606 - mae: 0.3934 - val_loss: 0.2423 - val_mae: 0.4113 - learning_rate: 5.0000e-04
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.2603 - mae: 0.4094 - val_loss: 0.2194 - val_mae: 0.3723 - learning_rate: 5.0000e-04
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.2327 - mae: 0.3710 - val_loss: 0.2168 - val_mae: 0.3597 - learning_rate: 5.0000e-04
# Epoch 9/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2160 - mae: 0.3360 - val_loss: 0.2133 - val_mae: 0.3634 - learning_rate: 5.0000e-04
# Epoch 10/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.2223 - mae: 0.3526 - val_loss: 0.1880 - val_mae: 0.3139 - learning_rate: 5.0000e-04
# Epoch 11/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2001 - mae: 0.3134 - val_loss: 0.1673 - val_mae: 0.2664 - learning_rate: 5.0000e-04
# Epoch 12/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.
- learning_rate: 5.0000e-04
# Epoch 72/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0783 - mae: 0.1290 - val_loss: 0.0673 - val_mae: 0.0602 - learning_rate: 5.0000e-04
# Epoch 73/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0768 - mae: 0.1248 - val_loss: 0.0653 - val_mae: 0.0402 - learning_rate: 5.0000e-04
# Epoch 74/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0749 - mae: 0.1165 - val_loss: 0.0648 - val_mae: 0.0411 - learning_rate: 5.0000e-04
# Epoch 75/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0755 - mae: 0.1262 - val_loss: 0.0642 - val_mae: 0.0396 - learning_rate: 5.0000e-04
# Epoch 76/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0747 - mae: 0.1195 - val_loss: 0.0648 - val_mae: 0.0505 - learning_rate: 5.0000e-04
# Epoch 77/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0758 - mae: 0.1286 - val_loss: 0.0655 - val_mae: 0.0648 - learning_rate: 5.0000e-04
# Epoch 78/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0741 - mae: 0.1274 - val_loss: 0.0629 - val_mae: 0.0479 - learning_rate: 5.0000e-04
# Epoch 79/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0732 - mae: 0.1215 - val_loss: 0.0630 - val_mae: 0.0504 - learning_rate: 5.0000e-04
# Epoch 80/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0752 - mae: 0.1346 - val_loss: 0.0635 - val_mae: 0.0603 - learning_rate: 5.0000e-04
# Epoch 81/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0763 - mae: 0.1378 - val_loss: 0.0625 - val_mae: 0.0591 - learning_rate: 5.0000e-04
# Epoch 82/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0710 - mae: 0.1177 - val_loss: 0.0606 - val_mae: 0.0439 - learning_rate: 5.0000e-04
# Epoch 83/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0704 - mae: 0.1202 - val_loss: 0.0599 - val_mae: 0.0411 - learning_rate: 5.0000e-04
# Epoch 84/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0700 - mae: 0.1166 - val_loss: 0.0590 - val_mae: 0.0327 - learning_rate: 5.0000e-04
# Epoch 85/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0691 - mae: 0.1103 - val_loss: 0.0591 - val_mae: 0.0418 - learning_rate: 5.0000e-04
# Epoch 86/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0664 - mae: 0.1022 - val_loss: 0.0588 - val_mae: 0.0430 - learning_rate: 5.0000e-04
# Epoch 87/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0704 - mae: 0.1277 - val_loss: 0.0581 - val_mae: 0.0424 - learning_rate: 5.0000e-04
# Epoch 88/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0685 - mae: 0.1210 - val_loss: 0.0577 - val_mae: 0.0446 - learning_rate: 5.0000e-04
# Epoch 89/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0655 - mae: 0.1069 - val_loss: 0.0575 - val_mae: 0.0490 - learning_rate: 5.0000e-04
# Epoch 90/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0661 - mae: 0.1135 - val_loss: 0.0565 - val_mae: 0.0386 - learning_rate: 5.0000e-04
# Epoch 91/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0657 - mae: 0.1124 - val_loss: 0.0556 - val_mae: 0.0325 - learning_rate: 5.0000e-04
# Epoch 92/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0654 - mae: 0.1156 - val_loss: 0.0559 - val_mae: 0.0427 - learning_rate: 5.0000e-04
# Epoch 93/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0660 - mae: 0.1191 - val_loss: 0.0554 - val_mae: 0.0417 - learning_rate: 5.0000e-04
# Epoch 94/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0643 - mae: 0.1140 - val_loss: 0.0550 - val_mae: 0.0450 - learning_rate: 5.0000e-04
# Epoch 95/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0634 - mae: 0.1138 - val_loss: 0.0546 - val_mae: 0.0417 - learning_rate: 5.0000e-04
# Epoch 96/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0616 - mae: 0.1025 - val_loss: 0.0538 - val_mae: 0.0370 - learning_rate: 5.0000e-04
# Epoch 97/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0630 - mae: 0.1122 - val_loss: 0.0536 - val_mae: 0.0424 - learning_rate: 5.0000e-04
# Epoch 98/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0638 - mae: 0.1170 - val_loss: 0.0526 - val_mae: 0.0323 - learning_rate: 5.0000e-04
# Epoch 99/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0637 - mae: 0.1222 - val_loss: 0.0532 - val_mae: 0.0430 - learning_rate: 5.0000e-04
# Epoch 100/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0624 - mae: 0.1173 - val_loss: 0.0524 - val_mae: 0.0438 - learning_rate: 5.0000e-04
# Epoch 101/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0630 - mae: 0.1233 - val_loss: 0.0519 - val_mae: 0.0385 - learning_rate: 5.0000e-04
# Epoch 102/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0632 - mae: 0.1247 - val_loss: 0.0514 - val_mae: 0.0354 - learning_rate: 5.0000e-04
# Epoch 103/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0607 - mae: 0.1141 - val_loss: 0.0512 - val_mae: 0.0444 - learning_rate: 5.0000e-04
# Epoch 104/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0635 - mae: 0.1269 - val_loss: 0.0507 - val_mae: 0.0412 - learning_rate: 5.0000e-04
# Epoch 105/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0593 - mae: 0.1139 - val_loss: 0.0499 - val_mae: 0.0381 - learning_rate: 5.0000e-04
# Epoch 106/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0572 - mae: 0.1049 - val_loss: 0.0496 - val_mae: 0.0355 - learning_rate: 5.0000e-04
# Epoch 107/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0585 - mae: 0.1083 - val_loss: 0.0494 - val_mae: 0.0388 - learning_rate: 5.0000e-04
# Epoch 108/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0596 - mae: 0.1151 - val_loss: 0.0489 - val_mae: 0.0365 - learning_rate: 5.0000e-04
# Epoch 109/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0577 - mae: 0.1092 - val_loss: 0.0491 - val_mae: 0.0441 - learning_rate: 5.0000e-04
# Epoch 110/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0578 - mae: 0.1137 - val_loss: 0.0481 - val_mae: 0.0347 - learning_rate: 5.0000e-04
# Epoch 111/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0583 - mae: 0.1165 - val_loss: 0.0492 - val_mae: 0.0462 - learning_rate: 5.0000e-04
# Epoch 112/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0604 - mae: 0.1298 - val_loss: 0.0478 - val_mae: 0.0421 - learning_rate: 5.0000e-04
# Epoch 113/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0578 - mae: 0.1173 - val_loss: 0.0469 - val_mae: 0.0341 - learning_rate: 5.0000e-04
# Epoch 114/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0556 - mae: 0.1108 - val_loss: 0.0469 - val_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 115/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0552 - mae: 0.1116 - val_loss: 0.0465 - val_mae: 0.0389 - learning_rate: 5.0000e-04
# Epoch 116/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0570 - mae: 0.1226 - val_loss: 0.0469 - val_mae: 0.0477 - learning_rate: 5.0000e-04
# Epoch 117/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0549 - mae: 0.1110 - val_loss: 0.0463 - val_mae: 0.0468 - learning_rate: 5.0000e-04
# Epoch 118/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0525 - mae: 0.0989 - val_loss: 0.0451 - val_mae: 0.0348 - learning_rate: 5.0000e-04
# Epoch 119/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0534 - mae: 0.1072 - val_loss: 0.0460 - val_mae: 0.0480 - learning_rate: 5.0000e-04
# Epoch 120/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0532 - mae: 0.1070 - val_loss: 0.0445 - val_mae: 0.0340 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 120.
#
# RESULTADOS FOLD
# MAE  : 45.87 m
# RMSE : 87.18 m
# R2  : 0.9901
#
#
# ============================================================
# RESUMEN LSTM V9 MEJORADA
# ============================================================
# MAE  : 51.84 ± 5.99 m
# RMSE : 101.31 ± 7.52 m
# R2   : 0.9866
# ============================================================
